# %% [markdown]
# # Regressão Softmax com dados do MNIST utilizando gradiente descendente estocástico por minibatches

# %% [markdown]
# O objetivo deste notebook é ilustrar
# - o uso do gradiente estocástico por mini-batchs
# - utilizando as classes Dataset e DataLoater.
#
# A apresentação da perda nos gráficos é um pouco diferente da usual, mostrando a perda de cada um dos vários minibatches dentro de cada época, de forma que as épocas são apresentadas com valores fracionários.

# %% [markdown]
# ## Importação das bibliotecas

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
from torch.utils.data import DataLoader

import torchvision
from torchvision.datasets import MNIST

# %% [markdown]
# ## Dataset e dataloader

# %% [markdown]
# ### Definição do tamanho do minibatch

# %%
batch_size = 100

# %% [markdown]
# ### Carregamento, criação dataset e do dataloader

# %%
dataset_dir = 'MNIST/'

dataset_train = MNIST(dataset_dir, train=True, download=True,
                      transform=torchvision.transforms.ToTensor())

loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

print('Número de minibatches de trenamento:', len(loader_train))

x_train, y_train = next(iter(loader_train))
print("\nDimensões dos dados de um minibatch:", x_train.size())
print("Valores mínimo e máximo dos pixels: ", torch.min(x_train), torch.max(x_train))
print("Tipo dos dados das imagens:         ", type(x_train))
print("Tipo das classes das imagens:       ", type(y_train))
# Out:
# Número de minibatches de trenamento: 600
#
# Dimensões dos dados de um minibatch: torch.Size([100, 1, 28, 28])
# Valores mínimo e máximo dos pixels:  tensor(0.) tensor(1.)
# Tipo dos dados das imagens:          <class 'torch.Tensor'>
# Tipo das classes das imagens:        <class 'torch.Tensor'>

# %% [markdown]
# ### Usando todas as amostras do MNIST
#
# Neste exemplo utilizaremos todas as amostras de treinamento.

# %%
print('Número de minibatches de trenamento:', len(loader_train))
n_batches_train = len(loader_train)
total_samples = dataset_train.train_data.size(0)
# Out:
# Número de minibatches de trenamento: 600
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py:76: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")

# %% [markdown]
# ## Modelo

# %%
model = torch.nn.Linear(28*28, 10)

# %%
x = torch.ones(28*28).reshape(1, 784)
print(x.shape)
predict = model(x)
predict
# Out:
# torch.Size([1, 784])
# tensor([[ 0.3928, -0.0991, -0.2693, -0.3966,  0.4216,  0.1557, -0.1352,  0.3670,
#           0.0096, -1.0852]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Inicialização dos parâmetros

# %%
n_epochs = 5
learningRate = 0.5

# Utilizaremos CrossEntropyLoss como função de perda
criterion = torch.nn.CrossEntropyLoss()

# Gradiente descendente
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

# %% [markdown]
# ### Laço de treinamento dos parâmetros

# %%
epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))
        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

# %%
print('Final loss:', loss.data)
# Out:
# Final loss: tensor(0.3855)

# %% [markdown]
# ### Visualizando gráfico de perda durante o treinamento

# %%
plt.plot(epochs, losses)
plt.xlabel('época')
# Out:
# Text(0.5, 0, 'época')

# %% [markdown]
# ### Visualização usual da perda, somente no final de cada época

# %%
plt.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
plt.title(f'Perda [batch_size = {batch_size}]')
plt.xlabel('época')
plt.show()

# %% [markdown]
# # Atividades

# %% [markdown]
# ## Perguntas

# %% [markdown]
# 1. Qual é o tamanho do mini-batch?
#
#   **R:** Cada mini-batch possui o tamanho 100 (amostras).
#
# 2. Em uma época, quantos mini-batches existem?
#
#   **R:** Como são 60 mil amostras e cada mini-batch possui 100 amostras, tem-se 600 mini-batches.
#
# 3. Qual é a definição de época?
#
#   **R:** É um ciclo, ou loop, onde todas as amostras são avaliadas pelo modelo diretamente ou por mini-batches. Ao final da avaliação, antes do fim de cada época, é calculada a perda e os pesos da rede são atualizados.

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Coloque um print no final de cada minibatch, no mesmo estilo do print do final de época, no seguinte estilo:
#     - Época: 1/4, batch: 600

# %%
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))
        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

        # Exercício 1
        print(f'Época: {i+1}/{n_epochs}, batch: {k+1}')
# Out:
# Época: 1/5, batch: 1
# Época: 1/5, batch: 2
# Época: 1/5, batch: 3
# Época: 1/5, batch: 4
# Época: 1/5, batch: 5
# Época: 1/5, batch: 6
# Época: 1/5, batch: 7
# Época: 1/5, batch: 8
# Época: 1/5, batch: 9
# Época: 1/5, batch: 10
# Época: 1/5, batch: 11
# Época: 1/5, batch: 12
# Época: 1/5, batch: 13
# Época: 1/5, batch: 14
# Época: 1/5, batch: 15
# Época: 1/5, batch: 16
# Época: 1/5, batch: 17
# Época: 1/5, batch: 18
# Época: 1/5, batch: 19
# Época: 1/5, batch: 20
# Época: 1/5, batch: 21
# Época: 1/5, batch: 22
# Época: 1/5, batch: 23
# Época: 1/5, batch: 24
# Época: 1/5, batch: 25
# Época: 1/5, batch: 26
# Época: 1/5, batch: 27
# Época: 1/5, batch: 28
# Época: 1/5, batch: 29
# Época: 1/5, batch: 30
# Época: 1/5, batch: 31
# Época: 1/5, batch: 32
# Época: 1/5, batch: 33
# Época: 1/5, batch: 34
# Época: 1/5, batch: 35
# Época: 1/5, batch: 36
# Época: 1/5, batch: 37
# Época: 1/5, batch: 38
# Época: 1/5, batch: 39
# Época: 1/5, batch: 40
# Época: 1/5, batch: 41
# Época: 1/5, batch: 42
# ...

# %% [markdown]
# 2. Altere o tamanho de minibatch (batch_size) algumas vezes, refaça o treinamento, e compare no gráfico abaixo a queda da perda para cada tamanho de minibatch.

# %% [markdown]
# **R: Comparação entre os resultados de perda para os diferentes tamanhos de minibatches**
#
# Percebe-se que um minibatch pequeno (batch_size = 10, 50, 100 ou 250) há uma oscilsção maior entre as perdas em cada época. Da mesma forma que aumentando para 1000. O melhor resultado, ou seja, uma baixa oscilação foi obtida com minibatches de tamanho 500. Também é possível verificar que a perda cai muito mais rápido quanto maior for o batch size.

# %%
batch_size = 10

# Nova instância da rede
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))

        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(epochs, losses)
ax2.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
fig.suptitle(f'Perda [batch_size = {batch_size}]')
ax1.set_xlabel('época')
ax2.set_xlabel('época')
ax1.set_ylabel('loss')
ax2.set_ylabel('loss')
plt.show()

# %%
batch_size = 50

# Nova instância da rede
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))

        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(epochs, losses)
ax2.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
fig.suptitle(f'Perda [batch_size = {batch_size}]')
ax1.set_xlabel('época')
ax2.set_xlabel('época')
ax1.set_ylabel('loss')
ax2.set_ylabel('loss')
plt.show()

# %%
batch_size = 250

# Nova instância da rede
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))

        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(epochs, losses)
ax2.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
fig.suptitle(f'Perda [batch_size = {batch_size}]')
ax1.set_xlabel('época')
ax2.set_xlabel('época')
ax1.set_ylabel('loss')
ax2.set_ylabel('loss')
plt.show()

# %%
batch_size = 500

# Nova instância da rede
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))

        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(epochs, losses)
ax2.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
fig.suptitle(f'Perda [batch_size = {batch_size}]')
ax1.set_xlabel('época')
ax2.set_xlabel('época')
ax1.set_ylabel('loss')
ax2.set_ylabel('loss')
plt.show()

# %%
batch_size = 1000

# Nova instância da rede
model = torch.nn.Linear(28*28, 10)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

epochs = []
losses = []

total_trained_samples = 0
for i in range(n_epochs):
    for k,(x_train, y_train) in enumerate(loader_train):
        # Transforma a entrada para uma dimensão
        inputs = Variable(x_train.view(-1, 28 * 28))

        # predict da rede
        outputs = model(inputs)

        # calcula a perda
        loss = criterion(outputs, Variable(y_train))

        # zero, backpropagation, ajusta parâmetros pelo gradiente descendente
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_trained_samples += x_train.size(0)
        epochs.append(total_trained_samples / total_samples)
        losses.append(loss.data)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(epochs, losses)
ax2.plot(epochs[:5 * n_batches_train +1:n_batches_train], losses[:5 * n_batches_train+1:n_batches_train])
fig.suptitle(f'Perda [batch_size = {batch_size}]')
ax1.set_xlabel('época')
ax2.set_xlabel('época')
ax1.set_ylabel('loss')
ax2.set_ylabel('loss')
plt.show()

# %% [markdown]
# ## Conclusões sobre os experimentos deste notebook
